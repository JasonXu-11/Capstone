# %% [markdown]
# ## Data Collection

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
customers = pd.read_csv('data/Wholesale customers data.csv')

retail = pd.read_csv('data/Online Retail.csv')

# %%
customers.head()
# Out:
#    Channel  Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 0        2       3  12669  9656     7561     214              2674        1338
# 1        2       3   7057  9810     9568    1762              3293        1776
# 2        2       3   6353  8808     7684    2405              3516        7844
# 3        1       3  13265  1196     4221    6404               507        1788
# 4        2       3  22615  5410     7198    3915              1777        5185

# %%
# Check the number of data, 440 may be too small for prediction but is good enough to try clustering
customers.shape
# Out:
# (440, 8)

# %%
retail.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
retail.shape
# Out:
# (541909, 8)

# %% [markdown]
# ### Data Cleaning

# %%
customers.isnull().sum()
# Out:
# Channel             0
# Region              0
# Fresh               0
# Milk                0
# Grocery             0
# Frozen              0
# Detergents_Paper    0
# Delicassen          0
# dtype: int64

# %%
retail.isnull().sum()
# Out:
# InvoiceNo         0
# StockCode         0
# Description      31
# Quantity          0
# InvoiceDate       0
# UnitPrice         0
# CustomerID     2516
# Country           0
# dtype: int64

# %%
# Select 10000 sample to do clustering
retail = retail.sample(n=10_000, random_state=42 )

# %% [markdown]
# ### Data EDA

# %%
# Customers data type
customers.dtypes
# Out:
# Channel             int64
# Region              int64
# Fresh               int64
# Milk                int64
# Grocery             int64
# Frozen              int64
# Detergents_Paper    int64
# Delicassen          int64
# dtype: object

# %%
# Customers value
customers.describe()
# Out:
#           Channel      Region          Fresh          Milk       Grocery  \
# count  440.000000  440.000000     440.000000    440.000000    440.000000
# mean     1.322727    2.543182   12000.297727   5796.265909   7951.277273
# std      0.468052    0.774272   12647.328865   7380.377175   9503.162829
# min      1.000000    1.000000       3.000000     55.000000      3.000000
# 25%      1.000000    2.000000    3127.750000   1533.000000   2153.000000
# 50%      1.000000    3.000000    8504.000000   3627.000000   4755.500000
# 75%      2.000000    3.000000   16933.750000   7190.250000  10655.750000
# max      2.000000    3.000000  112151.000000  73498.000000  92780.000000
#
#              Frozen  Detergents_Paper    Delicassen
# count    440.000000        440.000000    440.000000
# mean    3071.931818       2881.493182   1524.870455
# std     4854.673333       4767.854448   2820.105937
# min       25.000000          3.000000      3.000000
# ...

# %%
customers['Region'].value_counts()
# Out:
# 3    316
# 1     77
# 2     47
# Name: Region, dtype: int64

# %%
sns.pairplot(customers)

# %%
# Customer consumption depends on channel
customers.groupby(by='Channel').mean().plot(kind = 'barh');

# %%
# customer consumption depends on region
customers.groupby(by='Region').mean().plot(kind ='barh');

# %%
# Retail data destribution
retail.describe()
# Out:
#            Quantity     UnitPrice    CustomerID
# count  10000.000000  10000.000000   7484.000000
# mean       9.902300      3.752336  15251.783805
# std       49.498622     21.785467   1718.939462
# min    -1350.000000      0.000000  12347.000000
# 25%        1.000000      1.250000  13882.750000
# 50%        3.000000      2.080000  15061.000000
# 75%       10.000000      4.130000  16781.250000
# max     2880.000000   1867.860000  18287.000000

# %%
sns.pairplot(retail)

# %%
# Create a RFM table
