# %% [markdown]
# ## Data Collection

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential

# %%
import matplotlib.pyplot as plt

# %%
# load all pictures in train dataset
train_ds = tf.keras.preprocessing.image_dataset_from_directory('Datasets/Photos/train/', 
                                                               seed = 42, 
                                                               image_size=(256,256),
                                                               batch_size=32,
                                                               shuffle=True)
# Out:
# Found 2467 files belonging to 4 classes.

# %% [markdown]
# ### Data Cleaning

# %%
# different folders' names
train_ds.class_names
# Out:
# ['Closed', 'Open', 'no_yawn', 'yawn']

# %%
# take function would show examples we want to observe  (https://www.tensorflow.org/datasets/overview)
ds = train_ds.take(1)  # take 1 example
for image,label in ds:    # tf.data.Dataset contains a dict of tf.Tensor ({'image': tf.Tensor, 'label': tf.Tensor})
    print(image.shape,label.shape)
    plt.imshow(image[1].numpy().astype("uint8"))     # display data as image
    plt.title(train_ds.class_names[label[1]])
# Out:
# (32, 256, 256, 3) (32,)

# %%
# check 12 pictures  (https://www.kaggle.com/vanvalkenberg/drowsiness-detection-model-tensorflow)
plt.figure(figsize=(10,10))
for image,label in ds:    # tf.data.Dataset contains a dict of tf.Tensor ({'image': tf.Tensor, 'label': tf.Tensor})
    print(image.shape,label.shape)
    for i in range(12):
        ax = plt.subplot(3,4,i+1)
        plt.imshow(image[i].numpy().astype("uint8"))     # display data as image
        plt.title(train_ds.class_names[label[i]])
# Out:
# (32, 256, 256, 3) (32,)

# %%
image[0][0][0][0]
# Out:
# <tf.Tensor: shape=(3,), dtype=float32, numpy=array([169.5625, 170.5625, 165.5625], dtype=float32)>

# %%
label[0][0][0][0]
# Out:
# <tf.Tensor: shape=(3,), dtype=float32, numpy=array([69., 62., 54.], dtype=float32)>

# %%
plt.figure(figsize=(12,12))

# %% [markdown]
# ### Data EDA
